# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramsai-g/First-Project-AI/blob/master/First_Repository.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x='mean(Miles_per_Gallon)',
  y='Origin',
  color='Origin'
  
)
# Out:
# alt.Chart(...)

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf

import numpy as np

# %%
print("Bar chart")
# Out:
# Bar chart

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
celsius_q    = np.array([-40, -10,  0,  8, 15, 22,  38],  dtype=float)
fahrenheit_a = np.array([-40,  14, 32, 46, 59, 72, 100],  dtype=float)

for i,c in enumerate(celsius_q):
  print("{} degrees Celsius = {} degrees Fahrenheit".format(c, fahrenheit_a[i]))
# Out:
# -40.0 degrees Celsius = -40.0 degrees Fahrenheit
# -10.0 degrees Celsius = 14.0 degrees Fahrenheit
# 0.0 degrees Celsius = 32.0 degrees Fahrenheit
# 8.0 degrees Celsius = 46.0 degrees Fahrenheit
# 15.0 degrees Celsius = 59.0 degrees Fahrenheit
# 22.0 degrees Celsius = 72.0 degrees Fahrenheit
# 38.0 degrees Celsius = 100.0 degrees Fahrenheit

# %%
l0 = tf.keras.layers.Dense(units=1, input_shape=[1])

# %%
model = tf.keras.Sequential([l0])

# %%
model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(0.1))

# %%
history = model.fit(celsius_q, fahrenheit_a, epochs=500, verbose=False)
print("Finished training the model")
# Out:
# Finished training the model

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.ylabel("Loss Magnitude")
plt.plot(history.history['loss'])

# %%
print(model.predict([100.0]))
# Out:
# [[211.74742]]

# %%
print("These are the layer variables: {}".format(l0.get_weights()))
# Out:
# These are the layer variables: [array([[1.8219786]], dtype=float32), array([29.130219], dtype=float32)]

# %%
l0 = tf.keras.layers.Dense(units=4, input_shape=[1])
l1 = tf.keras.layers.Dense(units=4)
l2 = tf.keras.layers.Dense(units=1)
model = tf.keras.Sequential([l0, l1, l2])
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.1))
model.fit(celsius_q, fahrenheit_a, epochs=500, verbose=False)
print("Finished training the model")
print(model.predict([100.0]))
print("Model predicts that 100 degrees Celsius is: {} degrees Fahrenheit".format(model.predict([100.0])))
print("These are the l0 variables: {}".format(l0.get_weights()))
print("These are the l1 variables: {}".format(l1.get_weights()))
print("These are the l2 variables: {}".format(l2.get_weights()))
# Out:
# Finished training the model
# [[211.74742]]
# Model predicts that 100 degrees Celsius is: [[211.74742]] degrees Fahrenheit
# These are the l0 variables: [array([[ 0.7529907 , -0.08698119,  0.19994932,  0.12002631]],
#       dtype=float32), array([ 3.204871 , -3.102251 ,  3.1166546, -1.6744318], dtype=float32)]
# These are the l1 variables: [array([[-0.57200736, -0.62978923,  0.53779924,  0.24518433],
#        [ 0.98045975,  0.79781187,  0.3207354 ,  0.22209607],
#        [-0.8912613 , -0.6887582 , -0.87561214,  0.32733604],
#        [-0.44947377,  0.30584946, -0.03972017, -0.71427625]],
#       dtype=float32), array([-2.9436157, -3.085566 ,  0.4547624,  2.8964252], dtype=float32)]
# These are the l2 variables: [array([[-0.948461  ],
#        [-1.4613031 ],
#        [ 0.07496331],
#        [ 0.9072797 ]], dtype=float32), array([3.0403364], dtype=float32)]
